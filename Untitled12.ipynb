# %% [markdown]
# <a href="https://colab.research.google.com/github/gobbledy-gook/AskIt/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
featuresRF = {
    "url": 0.0261,
"length_url": 0.0169,
"length_hostname": 0.0169,
"ip": 0.0065,
"nb_dots": 0.0092,
"nb_hyphens": 0.0091,
"nb_at": 0.0003,
"nb_qm": 0.0054,
"nb_and": 0.0010,
"nb_or": 0.0000,
"nb_eq": 0.0047,
"nb_underscore": 0.0022,
"nb_tilde": 0.0001,
"nb_percent": 0.0014,
"nb_slash": 0.0132,
"nb_star": 0.0000,
"nb_colon": 0.0008,
"nb_comma": 0.0001,
"nb_semicolumn": 0.0007,
"nb_dollar": 0.0000,
"nb_space": 0.0009,
"nb_www": 0.0470,
"nb_com": 0.0008,
"nb_dslash": 0.0002,
"http_in_path": 0.0009,
"https_token": 0.0023,
"ratio_digits_url": 0.0189,
"ratio_digits_host": 0.0087,
"punycode": 0.0000,
"port": 0.0003,
"tld_in_path": 0.0006,
"tld_in_subdomain": 0.0009,
"abnormal_subdomain": 0.0004,
"nb_subdomains": 0.0041,
"prefix_suffix": 0.0017,
"random_domain": 0.0008,
"shortening_service": 0.0024,
"path_extension": 0.0000,
"nb_redirection": 0.0038,
"nb_external_redirection": 0.0000,
"length_words_raw": 0.0124,
"char_repeat": 0.0138,
"shortest_words_raw": 0.0078,
"shortest_word_host": 0.0104,
"shortest_word_path": 0.0090,
"longest_words_raw": 0.0160,
"longest_word_host": 0.0073,
"longest_word_path": 0.0305,
"avg_words_raw": 0.0089,
"avg_word_host": 0.0089,
"avg_word_path": 0.0178,
"phish_hints": 0.0237,
"domain_in_brand": 0.0040,
"brand_in_subdomain": 0.0001,
"brand_in_path": 0.0001,
"suspecious_tld": 0.0011,
"statistical_report": 0.0009,
"nb_hyperlinks": 0.0920,
"ratio_intHyperlinks": 0.0292,
"ratio_extHyperlinks": 0.0245,
"ratio_nullHyperlinks": 0.0000,
"nb_extCSS": 0.0037,
"ratio_intRedirection": 0.0000,
"ratio_extRedirection": 0.0183,
"ratio_intErrors": 0.0000,
"ratio_extErrors": 0.0051,
"login_form": 0.0011,
"external_favicon": 0.0018,
"links_in_tags": 0.0146,
"submit_email": 0.0000,
"ratio_intMedia": 0.0047,
"ratio_extMedia": 0.0057,
"sfh": 0.0000,
"iframe": 0.0001,
"popup_window": 0.0002,
"safe_anchor": 0.0192,
"onmouseover": 0.0000,
"right_clic": 0.0001,
"empty_title": 0.0016,
"domain_in_title": 0.0125,
"domain_with_copyright": 0.0064,
"whois_registered_domain": 0.0007,
"domain_registration_length": 0.0128,
"domain_age": 0.0304,
"web_traffic": 0.0614,
"dns_record": 0.0013,
"google_index": 0.1570,
"page_rank": 0.1138
}

# %%
featuresET = {
    "url": 0.0184,
"length_url": 0.0097,
"length_hostname": 0.0116,
"ip": 0.0270,
"nb_dots": 0.0099,
"nb_hyphens": 0.0097,
"nb_at": 0.0020,
"nb_qm": 0.0149,
"nb_and": 0.0012,
"nb_or": 0.0000,
"nb_eq": 0.0045,
"nb_underscore": 0.0038,
"nb_tilde": 0.0004,
"nb_percent": 0.0023,
"nb_slash": 0.0118,
"nb_star": 0.0000,
"nb_colon": 0.0014,
"nb_comma": 0.0001,
"nb_semicolumn": 0.0008,
"nb_dollar": 0.0000,
"nb_space": 0.0016,
"nb_www": 0.0629,
"nb_com": 0.0024,
"nb_dslash": 0.0005,
"http_in_path": 0.0017,
"https_token": 0.0054,
"ratio_digits_url": 0.0202,
"ratio_digits_host": 0.0081,
"punycode": 0.0000,
"port": 0.0005,
"tld_in_path": 0.0017,
"tld_in_subdomain": 0.0051,
"abnormal_subdomain": 0.0023,
"nb_subdomains": 0.0123,
"prefix_suffix": 0.0107,
"random_domain": 0.0026,
"shortening_service": 0.0060,
"path_extension": 0.0001,
"nb_redirection": 0.0078,
"nb_external_redirection": 0.0000,
"length_words_raw": 0.0094,
"char_repeat": 0.0088,
"shortest_words_raw": 0.0085,
"shortest_word_host": 0.0113,
"shortest_word_path": 0.0074,
"longest_words_raw": 0.0088,
"longest_word_host": 0.0070,
"longest_word_path": 0.0105,
"avg_words_raw": 0.0072,
"avg_word_host": 0.0078,
"avg_word_path": 0.0082,
"phish_hints": 0.0259,
"domain_in_brand": 0.0099,
"brand_in_subdomain": 0.0002,
"brand_in_path": 0.0003,
"suspecious_tld": 0.0026,
"statistical_report": 0.0025,
"nb_hyperlinks": 0.0226,
"ratio_intHyperlinks": 0.0216,
"ratio_extHyperlinks": 0.0168,
"ratio_nullHyperlinks": 0.0000,
"nb_extCSS": 0.0049,
"ratio_intRedirection": 0.0000,
"ratio_extRedirection": 0.0090,
"ratio_intErrors": 0.0000,
"ratio_extErrors": 0.0060,
"login_form": 0.0028,
"external_favicon": 0.0084,
"links_in_tags": 0.0205,
"submit_email": 0.0000,
"ratio_intMedia": 0.0117,
"ratio_extMedia": 0.0117,
"sfh": 0.0000,
"iframe": 0.0002,
"popup_window": 0.0007,
"safe_anchor": 0.0242,
"onmouseover": 0.0000,
"right_clic": 0.0002,
"empty_title": 0.0084,
"domain_in_title": 0.0325,
"domain_with_copyright": 0.0156,
"whois_registered_domain": 0.0025,
"domain_registration_length": 0.0090,
"domain_age": 0.0269,
"web_traffic": 0.0079,
"dns_record": 0.0024,
"google_index": 0.2425,
"page_rank": 0.0737
}

# %%
featuresXGB = {
    "url": 0.0028,
"length_url": 0.0039,
"length_hostname": 0.0062,
"ip": 0.0154,
"nb_dots": 0.0062,
"nb_hyphens": 0.0088,
"nb_at": 0.0035,
"nb_qm": 0.0448,
"nb_and": 0.0027,
"nb_or": 0.0000,
"nb_eq": 0.0040,
"nb_underscore": 0.0070,
"nb_tilde": 0.0000,
"nb_percent": 0.0053,
"nb_slash": 0.0069,
"nb_star": 0.0000,
"nb_colon": 0.0164,
"nb_comma": 0.0000,
"nb_semicolumn": 0.0022,
"nb_dollar": 0.0000,
"nb_space": 0.0096,
"nb_www": 0.0292,
"nb_com": 0.0051,
"nb_dslash": 0.0000,
"http_in_path": 0.0000,
"https_token": 0.0000,
"ratio_digits_url": 0.0050,
"ratio_digits_host": 0.0251,
"punycode": 0.0000,
"port": 0.0106,
"tld_in_path": 0.0029,
"tld_in_subdomain": 0.0021,
"abnormal_subdomain": 0.0000,
"nb_subdomains": 0.0000,
"prefix_suffix": 0.0028,
"random_domain": 0.0033,
"shortening_service": 0.0077,
"path_extension": 0.0000,
"nb_redirection": 0.0024,
"nb_external_redirection": 0.0000,
"length_words_raw": 0.0121,
"char_repeat": 0.0046,
"shortest_words_raw": 0.0026,
"shortest_word_host": 0.0044,
"shortest_word_path": 0.0062,
"longest_words_raw": 0.0057,
"longest_word_host": 0.0025,
"longest_word_path": 0.0105,
"avg_words_raw": 0.0024,
"avg_word_host": 0.0022,
"avg_word_path": 0.0021,
"phish_hints": 0.0185,
"domain_in_brand": 0.0132,
"brand_in_subdomain": 0.0000,
"brand_in_path": 0.0000,
"suspecious_tld": 0.0209,
"statistical_report": 0.0024,
"nb_hyperlinks": 0.0272,
"ratio_intHyperlinks": 0.0030,
"ratio_extHyperlinks": 0.0058,
"ratio_nullHyperlinks": 0.0000,
"nb_extCSS": 0.0026,
"ratio_intRedirection": 0.0000,
"ratio_extRedirection": 0.0033,
"ratio_intErrors": 0.0000,
"ratio_extErrors": 0.0029,
"login_form": 0.0021,
"external_favicon": 0.0024,
"links_in_tags": 0.0034,
"submit_email": 0.0000,
"ratio_intMedia": 0.0027,
"ratio_extMedia": 0.0037,
"sfh": 0.0000,
"iframe": 0.0000,
"popup_window": 0.0000,
"safe_anchor": 0.0049,
"onmouseover": 0.0000,
"right_clic": 0.0000,
"empty_title": 0.0026,
"domain_in_title": 0.0098,
"domain_with_copyright": 0.0030,
"whois_registered_domain": 0.0026,
"domain_registration_length": 0.0027,
"domain_age": 0.0055,
"web_traffic": 0.0104,
"dns_record": 0.0000,
"google_index": 0.5102,
"page_rank": 0.0372
}

# %%
featuresCat = {
    "url": 1.8823,
"length_url": 1.9101,
"length_hostname": 1.9312,
"ip": 0.6590,
"nb_dots": 1.4980,
"nb_hyphens": 2.9463,
"nb_at": 0.0247,
"nb_qm": 1.7899,
"nb_and": 0.0661,
"nb_or": 0.0000,
"nb_eq": 0.4843,
"nb_underscore": 0.6986,
"nb_tilde": 0.0058,
"nb_percent": 0.4238,
"nb_slash": 3.4576,
"nb_star": 0.0000,
"nb_colon": 0.1800,
"nb_comma": 0.0003,
"nb_semicolumn": 0.0729,
"nb_dollar": 0.0000,
"nb_space": 0.1385,
"nb_www": 6.5661,
"nb_com": 0.1263,
"nb_dslash": 0.0000,
"http_in_path": 0.0384,
"https_token": 0.3121,
"ratio_digits_url": 1.8041,
"ratio_digits_host": 1.9160,
"punycode": 0.0000,
"port": 0.0129,
"tld_in_path": 0.1657,
"tld_in_subdomain": 0.0057,
"abnormal_subdomain": 0.0143,
"nb_subdomains": 0.6643,
"prefix_suffix": 0.0621,
"random_domain": 0.0540,
"shortening_service": 0.3073,
"path_extension": 0.0014,
"nb_redirection": 0.2751,
"nb_external_redirection": 0.0000,
"length_words_raw": 2.2839,
"char_repeat": 0.4946,
"shortest_words_raw": 0.6181,
"shortest_word_host": 0.6676,
"shortest_word_path": 1.5517,
"longest_words_raw": 0.7455,
"longest_word_host": 0.3466,
"longest_word_path": 3.4761,
"avg_words_raw": 0.5859,
"avg_word_host": 0.5607,
"avg_word_path": 1.1242,
"phish_hints": 3.7264,
"domain_in_brand": 1.2887,
"brand_in_subdomain": 0.0000,
"brand_in_path": 0.0012,
"suspecious_tld": 0.1807,
"statistical_report": 0.0831,
"nb_hyperlinks": 6.5420,
"ratio_intHyperlinks": 1.2907,
"ratio_extHyperlinks": 1.3794,
"ratio_nullHyperlinks": 0.0000,
"nb_extCSS": 0.3646,
"ratio_intRedirection": 0.0000,
"ratio_extRedirection": 1.0643,
"ratio_intErrors": 0.0000,
"ratio_extErrors": 0.6539,
"login_form": 0.1044,
"external_favicon": 0.4697,
"links_in_tags": 0.7208,
"submit_email": 0.0000,
"ratio_intMedia": 0.6816,
"ratio_extMedia": 0.5648,
"sfh": 0.0000,
"iframe": 0.0064,
"popup_window": 0.0116,
"safe_anchor": 1.5065,
"onmouseover": 0.0003,
"right_clic": 0.0000,
"empty_title": 0.4354,
"domain_in_title": 0.8020,
"domain_with_copyright": 0.8501,
"whois_registered_domain": 0.0422,
"domain_registration_length": 2.2368,
"domain_age": 4.3676,
"web_traffic": 3.3290,
"dns_record": 0.0500,
"google_index": 10.7683,
"page_rank": 13.5273
}

# %%
featuresAda = {
    "url": 0.0174,
"length_url": 0.0000,
"length_hostname": 0.0703,
"ip": 0.0211,
"nb_dots": 0.0000,
"nb_hyphens": 0.0368,
"nb_at": 0.0000,
"nb_qm": 0.0274,
"nb_and": 0.0000,
"nb_or": 0.0000,
"nb_eq": 0.0000,
"nb_underscore": 0.0000,
"nb_tilde": 0.0000,
"nb_percent": 0.0000,
"nb_slash": 0.0000,
"nb_star": 0.0000,
"nb_colon": 0.0000,
"nb_comma": 0.0000,
"nb_semicolumn": 0.0071,
"nb_dollar": 0.0000,
"nb_space": 0.0165,
"nb_www": 0.0587,
"nb_com": 0.0000,
"nb_dslash": 0.0000,
"http_in_path": 0.0000,
"https_token": 0.0000,
"ratio_digits_url": 0.0000,
"ratio_digits_host": 0.0683,
"punycode": 0.0000,
"port": 0.0000,
"tld_in_path": 0.0000,
"tld_in_subdomain": 0.0000,
"abnormal_subdomain": 0.0000,
"nb_subdomains": 0.0000,
"prefix_suffix": 0.0000,
"random_domain": 0.0000,
"shortening_service": 0.0170,
"path_extension": 0.0000,
"nb_redirection": 0.0000,
"nb_external_redirection": 0.0000,
"length_words_raw": 0.0070,
"char_repeat": 0.0000,
"shortest_words_raw": 0.0000,
"shortest_word_host": 0.0000,
"shortest_word_path": 0.0163,
"longest_words_raw": 0.0154,
"longest_word_host": 0.0000,
"longest_word_path": 0.0508,
"avg_words_raw": 0.0000,
"avg_word_host": 0.0000,
"avg_word_path": 0.0000,
"phish_hints": 0.0807,
"domain_in_brand": 0.0224,
"brand_in_subdomain": 0.0000,
"brand_in_path": 0.0000,
"suspecious_tld": 0.0000,
"statistical_report": 0.0000,
"nb_hyperlinks": 0.0876,
"ratio_intHyperlinks": 0.0132,
"ratio_extHyperlinks": 0.0193,
"ratio_nullHyperlinks": 0.0000,
"nb_extCSS": 0.0000,
"ratio_intRedirection": 0.0000,
"ratio_extRedirection": 0.0000,
"ratio_intErrors": 0.0000,
"ratio_extErrors": 0.0000,
"login_form": 0.0000,
"external_favicon": 0.0000,
"links_in_tags": 0.0000,
"submit_email": 0.0000,
"ratio_intMedia": 0.0000,
"ratio_extMedia": 0.0000,
"sfh": 0.0000,
"iframe": 0.0000,
"popup_window": 0.0000,
"safe_anchor": 0.0000,
"onmouseover": 0.0000,
"right_clic": 0.0000,
"empty_title": 0.0000,
"domain_in_title": 0.0312,
"domain_with_copyright": 0.0000,
"whois_registered_domain": 0.0000,
"domain_registration_length": 0.0000,
"domain_age": 0.0518,
"web_traffic": 0.0169,
"dns_record": 0.0000,
"google_index": 0.1370,
"page_rank": 0.1100
}

# %%
featuresLight = {
    "url": 122.0000,
"length_url": 92.0000,
"length_hostname": 115.0000,
"ip": 14.0000,
"nb_dots": 54.0000,
"nb_hyphens": 101.0000,
"nb_at": 14.0000,
"nb_qm": 34.0000,
"nb_and": 2.0000,
"nb_or": 0.0000,
"nb_eq": 8.0000,
"nb_underscore": 24.0000,
"nb_tilde": 0.0000,
"nb_percent": 22.0000,
"nb_slash": 104.0000,
"nb_star": 0.0000,
"nb_colon": 2.0000,
"nb_comma": 0.0000,
"nb_semicolumn": 12.0000,
"nb_dollar": 0.0000,
"nb_space": 13.0000,
"nb_www": 94.0000,
"nb_com": 8.0000,
"nb_dslash": 3.0000,
"http_in_path": 3.0000,
"https_token": 1.0000,
"ratio_digits_url": 66.0000,
"ratio_digits_host": 47.0000,
"punycode": 0.0000,
"port": 3.0000,
"tld_in_path": 6.0000,
"tld_in_subdomain": 5.0000,
"abnormal_subdomain": 1.0000,
"nb_subdomains": 0.0000,
"prefix_suffix": 5.0000,
"random_domain": 5.0000,
"shortening_service": 14.0000,
"path_extension": 0.0000,
"nb_redirection": 11.0000,
"nb_external_redirection": 0.0000,
"length_words_raw": 68.0000,
"char_repeat": 30.0000,
"shortest_words_raw": 42.0000,
"shortest_word_host": 45.0000,
"shortest_word_path": 45.0000,
"longest_words_raw": 62.0000,
"longest_word_host": 28.0000,
"longest_word_path": 73.0000,
"avg_words_raw": 55.0000,
"avg_word_host": 34.0000,
"avg_word_path": 41.0000,
"phish_hints": 84.0000,
"domain_in_brand": 30.0000,
"brand_in_subdomain": 0.0000,
"brand_in_path": 0.0000,
"suspecious_tld": 8.0000,
"statistical_report": 11.0000,
"nb_hyperlinks": 164.0000,
"ratio_intHyperlinks": 59.0000,
"ratio_extHyperlinks": 77.0000,
"ratio_nullHyperlinks": 0.0000,
"nb_extCSS": 18.0000,
"ratio_intRedirection": 0.0000,
"ratio_extRedirection": 38.0000,
"ratio_intErrors": 0.0000,
"ratio_extErrors": 33.0000,
"login_form": 7.0000,
"external_favicon": 16.0000,
"links_in_tags": 50.0000,
"submit_email": 0.0000,
"ratio_intMedia": 30.0000,
"ratio_extMedia": 32.0000,
"sfh": 0.0000,
"iframe": 0.0000,
"popup_window": 0.0000,
"safe_anchor": 63.0000,
"onmouseover": 0.0000,
"right_clic": 0.0000,
"empty_title": 6.0000,
"domain_in_title": 24.0000,
"domain_with_copyright": 15.0000,
"whois_registered_domain": 8.0000,
"domain_registration_length": 112.0000,
"domain_age": 210.0000,
"web_traffic": 114.0000,
"dns_record": 1.0000,
"google_index": 59.0000,
"page_rank": 203.0000
}

# %%
for k in featuresRF.keys():
  if(featuresRF[k] == 0.0 and featuresAda[k] == 0.0 and featuresCat[k] == 0.0
     and featuresET[k] == 0.0 and featuresLight[k] == 0.0 and featuresXGB[k] == 0.0):
    print(k)
# Out:
# nb_or
# nb_star
# nb_dollar
# punycode
# nb_external_redirection
# ratio_nullHyperlinks
# ratio_intRedirection
# ratio_intErrors
# submit_email
# sfh

# %%
print("RF", max(featuresRF.values()), min(featuresRF.values()))
print("Ada", max(featuresAda.values()), min(featuresAda.values()))
print("Cat",max(featuresCat.values()), min(featuresCat.values()))
print("ET", max(featuresET.values()), min(featuresET.values()))
print("Light", max(featuresLight.values()), min(featuresLight.values()))
print("XGB", max(featuresXGB.values()), min(featuresXGB.values()))

# %%
rf = max(featuresRF.values())
ada = max(featuresAda.values())
cat = max(featuresCat.values())
et = max(featuresET.values())
light = max(featuresLight.values())
xgb = max(featuresXGB.values())

for k in featuresRF.keys():
  if(featuresRF[k] < 0.03*rf and featuresAda[k] < 0.03*ada and featuresCat[k] < 0.03*cat
     and featuresET[k] < 0.03*et and featuresLight[k] < 0.03*light and featuresXGB[k] < 0.03*xgb):
    print(k)
# Out:
# nb_and
# nb_or
# nb_tilde
# nb_star
# nb_comma
# nb_dollar
# nb_dslash
# http_in_path
# https_token
# punycode
# port
# tld_in_path
# tld_in_subdomain
# abnormal_subdomain
# random_domain
# path_extension
# nb_external_redirection
# brand_in_subdomain
# brand_in_path
# ratio_nullHyperlinks
# ratio_intRedirection
# ratio_intErrors
# submit_email
# sfh
# iframe
# popup_window
# onmouseover
# right_clic
# dns_record

# %%
k = "phish_hints"
print("RF", featuresRF[k], max(featuresRF.values()), min(featuresRF.values()))
print("Ada", featuresAda[k], max(featuresAda.values()), min(featuresAda.values()))
print("Cat",featuresCat[k], max(featuresCat.values()), min(featuresCat.values()))
print("ET", featuresET[k], max(featuresET.values()), min(featuresET.values()))
print("Light",featuresLight[k], max(featuresLight.values()), min(featuresLight.values()))
print("XGB",featuresXGB[k], max(featuresXGB.values()), min(featuresXGB.values()))
# Out:
# RF 0.0237 0.157 0.0
# Ada 0.0807 0.137 0.0
# Cat 3.7264 13.5273 0.0
# ET 0.0259 0.2425 0.0
# Light 84.0 210.0 0.0
# XGB 0.0185 0.5102 0.0
